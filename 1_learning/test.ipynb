# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
x = torch.tensor([2.0 , 3.0 , 5.0])
y = torch.tensor([1.0 , 5.0 , 6.0])

# %%
x , y
# Out:
# (tensor([2., 3., 5.]), tensor([1., 5., 6.]))

# %%
z =  x + y
